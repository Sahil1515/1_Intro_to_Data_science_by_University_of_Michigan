# %%
import pandas as pd 
import numpy as np

# modifying 
print()
df=pd.read_csv(r'C:\Users\Sahil\Desktop\Data_Science\UM_DataSciWithPython_1\olympics.csv',index_col=0,skiprows=1) 
# df=pd.read_csv('C:/Users/Sahil/Downloads/olympics.csv',index_col=0,skiprows=[1,2,3,4])
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# Afghanistan (AFG)             2               2
# Algeria (ALG)                 8              15
# Argentina (ARG)              28              70
# Armenia (ARM)                 9              12
# Australasia (ANZ) [ANZ]       5              12

# %%
# Editting the csv file directily
df.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %%
for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]},inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]},inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]},inplace=True)

df.head()
# Out:
#                          № Summer  Gold  Silver  Bronze  Total  № Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  № Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
#                          Silver.2  Bronze.2  Combined total
# Afghanistan (AFG)               0         2               2
# Algeria (ALG)                   2         8              15
# Argentina (ARG)                24        28              70
# Armenia (ARM)                   2         9              12
# Australasia (ANZ) [ANZ]         4         5              12

# %%
names_ids = df.index.str.split('(') # split the index by '('
df.index = names_ids.str[0] # the [0] element is the country name (new index) 
df['ID'] = names_ids.str[1].str[:3] # the [1] element is the abbreviation or ID (take first 3 characters from that)
df.head()
# Out:
#               № Summer  Gold  Silver  Bronze  Total  № Winter  Gold.1  \
# Afghanistan         13     0       0       2      2         0       0
# Algeria             12     5       2       8     15         3       0
# Argentina           23    18      24      28     70        18       0
# Armenia              5     1       2       9     12         6       0
# Australasia          2     3       4       5     12         0       0
#
#               Silver.1  Bronze.1  Total.1  № Games  Gold.2  Silver.2  \
# Afghanistan          0         0        0       13       0         0
# Algeria              0         0        0       15       5         2
# Argentina            0         0        0       41      18        24
# Armenia              0         0        0       11       1         2
# Australasia          0         0        0        2       3         4
#
#               Bronze.2  Combined total   ID
# Afghanistan          2               2  AFG
# Algeria              8              15  ALG
# Argentina           28              70  ARG
# Armenia              9              12  ARM
# Australasia          5              12  ANZ

# %%
bool_array_with_summer_golds=df['Gold']>0
bool_array_with_summer_golds.head(15)
# Out:
# Afghanistan     False
# Algeria          True
# Argentina        True
# Armenia          True
# Australasia      True
# Australia        True
# Austria          True
# Azerbaijan       True
# Bahamas          True
# Bahrain         False
# Barbados        False
# Belarus          True
# Belgium          True
# Bermuda         False
# Bohemia         False
# Name: Gold, dtype: bool

# %%
# now we will overlay this boolean file over dataframe to get only those countries which got gold >0 in Summer
#For this we use: where as an dot function of the csv file container

only_gold=df.where(bool_array_with_summer_golds)
# or:only_gold=df.where(df['Gold']>0 )
only_gold.head(15)
# Out:
#               № Summer   Gold  Silver  Bronze  Total  № Winter  Gold.1  \
# Afghanistan        NaN    NaN     NaN     NaN    NaN       NaN     NaN
# Algeria           12.0    5.0     2.0     8.0   15.0       3.0     0.0
# Argentina         23.0   18.0    24.0    28.0   70.0      18.0     0.0
# Armenia            5.0    1.0     2.0     9.0   12.0       6.0     0.0
# Australasia        2.0    3.0     4.0     5.0   12.0       0.0     0.0
# Australia         25.0  139.0   152.0   177.0  468.0      18.0     5.0
# Austria           26.0   18.0    33.0    35.0   86.0      22.0    59.0
# Azerbaijan         5.0    6.0     5.0    15.0   26.0       5.0     0.0
# Bahamas           15.0    5.0     2.0     5.0   12.0       0.0     0.0
# Bahrain            NaN    NaN     NaN     NaN    NaN       NaN     NaN
# Barbados           NaN    NaN     NaN     NaN    NaN       NaN     NaN
# Belarus            5.0   12.0    24.0    39.0   75.0       6.0     6.0
# Belgium           25.0   37.0    52.0    53.0  142.0      20.0     1.0
# Bermuda            NaN    NaN     NaN     NaN    NaN       NaN     NaN
# Bohemia            NaN    NaN     NaN     NaN    NaN       NaN     NaN
#
#               Silver.1  Bronze.1  Total.1  № Games  Gold.2  Silver.2  \
# Afghanistan        NaN       NaN      NaN      NaN     NaN       NaN
# Algeria            0.0       0.0      0.0     15.0     5.0       2.0
# Argentina          0.0       0.0      0.0     41.0    18.0      24.0
# Armenia            0.0       0.0      0.0     11.0     1.0       2.0
# Australasia        0.0       0.0      0.0      2.0     3.0       4.0
# Australia          3.0       4.0     12.0     43.0   144.0     155.0
# Austria           78.0      81.0    218.0     48.0    77.0     111.0
# Azerbaijan         0.0       0.0      0.0     10.0     6.0       5.0
# Bahamas            0.0       0.0      0.0     15.0     5.0       2.0
# Bahrain            NaN       NaN      NaN      NaN     NaN       NaN
# Barbados           NaN       NaN      NaN      NaN     NaN       NaN
# Belarus            4.0       5.0     15.0     11.0    18.0      28.0
# Belgium            1.0       3.0      5.0     45.0    38.0      53.0
# Bermuda            NaN       NaN      NaN      NaN     NaN       NaN
# Bohemia            NaN       NaN      NaN      NaN     NaN       NaN
#
#               Bronze.2  Combined total   ID
# Afghanistan        NaN             NaN  NaN
# Algeria            8.0            15.0  ALG
# Argentina         28.0            70.0  ARG
# Armenia            9.0            12.0  ARM
# Australasia        5.0            12.0  ANZ
# Australia        181.0           480.0  AUS
# Austria          116.0           304.0  AUT
# Azerbaijan        15.0            26.0  AZE
# Bahamas            5.0            12.0  BAH
# Bahrain            NaN             NaN  NaN
# Barbados           NaN             NaN  NaN
# Belarus           44.0            90.0  BLR
# Belgium           56.0           147.0  BEL
# Bermuda            NaN             NaN  NaN
# Bohemia            NaN             NaN  NaN

# %%
# print(df.count())
# To check the effect of the above function we are checking the length of old and new data
print("Old data length: {}".format(df['Gold'].count()))
print("New data length: {}".format(only_gold['Gold'].count()))
# Out:
# Old data length: 147
# New data length: 100

# %% [markdown]
# ### Important: dropna()

# %%
# Now we will drop those rows which have the nan data or no data
print("Now we will drop those rows which have the nan data or no data")
only_gold=only_gold.dropna()
only_gold.head(10)
# Out:
# Now we will drop those rows which have the nan data or no data
#               № Summer   Gold  Silver  Bronze  Total  № Winter  Gold.1  \
# Algeria           12.0    5.0     2.0     8.0   15.0       3.0     0.0
# Argentina         23.0   18.0    24.0    28.0   70.0      18.0     0.0
# Armenia            5.0    1.0     2.0     9.0   12.0       6.0     0.0
# Australasia        2.0    3.0     4.0     5.0   12.0       0.0     0.0
# Australia         25.0  139.0   152.0   177.0  468.0      18.0     5.0
# Austria           26.0   18.0    33.0    35.0   86.0      22.0    59.0
# Azerbaijan         5.0    6.0     5.0    15.0   26.0       5.0     0.0
# Bahamas           15.0    5.0     2.0     5.0   12.0       0.0     0.0
# Belarus            5.0   12.0    24.0    39.0   75.0       6.0     6.0
# Belgium           25.0   37.0    52.0    53.0  142.0      20.0     1.0
#
#               Silver.1  Bronze.1  Total.1  № Games  Gold.2  Silver.2  \
# Algeria            0.0       0.0      0.0     15.0     5.0       2.0
# Argentina          0.0       0.0      0.0     41.0    18.0      24.0
# Armenia            0.0       0.0      0.0     11.0     1.0       2.0
# Australasia        0.0       0.0      0.0      2.0     3.0       4.0
# Australia          3.0       4.0     12.0     43.0   144.0     155.0
# Austria           78.0      81.0    218.0     48.0    77.0     111.0
# Azerbaijan         0.0       0.0      0.0     10.0     6.0       5.0
# Bahamas            0.0       0.0      0.0     15.0     5.0       2.0
# Belarus            4.0       5.0     15.0     11.0    18.0      28.0
# Belgium            1.0       3.0      5.0     45.0    38.0      53.0
#
#               Bronze.2  Combined total   ID
# Algeria            8.0            15.0  ALG
# Argentina         28.0            70.0  ARG
# Armenia            9.0            12.0  ARM
# Australasia        5.0            12.0  ANZ
# Australia        181.0           480.0  AUS
# Austria          116.0           304.0  AUT
# Azerbaijan        15.0            26.0  AZE
# Bahamas            5.0            12.0  BAH
# Belarus           44.0            90.0  BLR
# Belgium           56.0           147.0  BEL

# %%
len(only_gold)
# Out:
# 99

# %%
# Instead of all the above lines of the paragraph we could simply do it 
#without using the where clause
only_gold=df[df['Gold']>0]
only_gold.head(10)
# Out:
#               № Summer  Gold  Silver  Bronze  Total  № Winter  Gold.1  \
# Algeria             12     5       2       8     15         3       0
# Argentina           23    18      24      28     70        18       0
# Armenia              5     1       2       9     12         6       0
# Australasia          2     3       4       5     12         0       0
# Australia           25   139     152     177    468        18       5
# Austria             26    18      33      35     86        22      59
# Azerbaijan           5     6       5      15     26         5       0
# Bahamas             15     5       2       5     12         0       0
# Belarus              5    12      24      39     75         6       6
# Belgium             25    37      52      53    142        20       1
#
#               Silver.1  Bronze.1  Total.1  № Games  Gold.2  Silver.2  \
# Algeria              0         0        0       15       5         2
# Argentina            0         0        0       41      18        24
# Armenia              0         0        0       11       1         2
# Australasia          0         0        0        2       3         4
# Australia            3         4       12       43     144       155
# Austria             78        81      218       48      77       111
# Azerbaijan           0         0        0       10       6         5
# Bahamas              0         0        0       15       5         2
# Belarus              4         5       15       11      18        28
# Belgium              1         3        5       45      38        53
#
#               Bronze.2  Combined total   ID
# Algeria              8              15  ALG
# Argentina           28              70  ARG
# Armenia              9              12  ARM
# Australasia          5              12  ANZ
# Australia          181             480  AUS
# Austria            116             304  AUT
# Azerbaijan          15              26  AZE
# Bahamas              5              12  BAH
# Belarus             44              90  BLR
# Belgium             56             147  BEL

# %%
# Gold in winter or in Summer
print("Gold in winter or in Summer: {}".format(len(df[(df['Gold']>0) | (df['Gold.1']>0)])))

print("Gold in winter and not in summer: {}".format(len(df[(df['Gold']==0) & (df['Gold.1']>0)])))
df[(df['Gold']==0) & (df['Gold.1']>0)]
# Out:
# Gold in winter or in Summer: 101
# Gold in winter and not in summer: 1
#                 № Summer  Gold  Silver  Bronze  Total  № Winter  Gold.1  \
# Liechtenstein         16     0       0       0      0        18       2
#
#                 Silver.1  Bronze.1  Total.1  № Games  Gold.2  Silver.2  \
# Liechtenstein          2         5        9       34       2         2
#
#                 Bronze.2  Combined total   ID
# Liechtenstein          5               9  LIE

# %%
df.iloc[2]
# Out:
# № Summer           23
# Gold               18
# Silver             24
# Bronze             28
# Total              70
# № Winter           18
# Gold.1              0
# Silver.1            0
# Bronze.1            0
# Total.1             0
# № Games            41
# Gold.2             18
# Silver.2           24
# Bronze.2           28
# Combined total     70
# ID                ARG
# Name: Argentina , dtype: object

# %%
df.head(60)

# print(df.T['Afghanistan (AFG)']): Not working so how to access the row
# Out:
#                          № Summer  Gold  Silver  Bronze  Total  № Winter  \
# Afghanistan                    13     0       0       2      2         0
# Algeria                        12     5       2       8     15         3
# Argentina                      23    18      24      28     70        18
# Armenia                         5     1       2       9     12         6
# Australasia                     2     3       4       5     12         0
# Australia                      25   139     152     177    468        18
# Austria                        26    18      33      35     86        22
# Azerbaijan                      5     6       5      15     26         5
# Bahamas                        15     5       2       5     12         0
# Bahrain                         8     0       0       1      1         0
# Barbados                       11     0       0       1      1         0
# Belarus                         5    12      24      39     75         6
# Belgium                        25    37      52      53    142        20
# Bermuda                        17     0       0       1      1         7
# Bohemia                         3     0       1       3      4         0
# Botswana                        9     0       1       0      1         0
# Brazil                         21    23      30      55    108         7
# British West Indies             1     0       0       2      2         0
# Bulgaria                       19    51      85      78    214        19
# Burundi                         5     1       0       0      1         0
# Cameroon                       13     3       1       1      5         1
# Canada                         25    59      99     121    279        22
# Chile                          22     2       7       4     13        16
# China                           9   201     146     126    473        10
# Colombia                       18     2       6      11     19         1
# Costa Rica                     14     1       1       2      4         6
# Ivory Coast                    12     0       1       0      1         0
# Croatia                         6     6       7      10     23         7
# Cuba                           19    72      67      70    209         0
# Cyprus                          9     0       1       0      1        10
# Czech Republic                  5    14      15      15     44         6
# Czechoslovakia                 16    49      49      45    143        16
# Denmark                        26    43      68      68    179        13
# Djibouti                        7     0       0       1      1         0
# Dominican Republic             13     3       2       1      6         0
# Ecuador                        13     1       1       0      2         0
# Egypt                          21     7       9      10     26         1
# Eritrea                         4     0       0       1      1         0
# Estonia                        11     9       9      15     33         9
# Ethiopia                       12    21       7      17     45         2
# Finland                        24   101      84     117    302        22
# France                         27   202     223     246    671        22
# Gabon                           9     0       1       0      1         0
# Georgia                         5     6       5      14     25         6
# Germany                        15   174     182     217    573        11
# United Team of Germany          3    28      54      36    118         3
# East Germany                    5   153     129     127    409         6
# West Germany                    5    56      67      81    204         6
# Ghana                          13     0       1       3      4         1
# Great Britain                  27   236     272     272    780        22
# Greece                         27    30      42      39    111        18
# Grenada                         8     1       0       0      1         0
# Guatemala                      13     0       1       0      1         1
# Guyana                         16     0       0       1      1         0
# Haiti                          14     0       1       1      2         0
# Hong Kong                      15     1       1       1      3         4
# Hungary                        25   167     144     165    476        22
# Iceland                        19     0       2       2      4        17
# India                          23     9       6      11     26         9
# Indonesia                      14     6      10      11     27         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  № Games  Gold.2  \
# Afghanistan                   0         0         0        0       13       0
# Algeria                       0         0         0        0       15       5
# Argentina                     0         0         0        0       41      18
# Armenia                       0         0         0        0       11       1
# Australasia                   0         0         0        0        2       3
# Australia                     5         3         4       12       43     144
# Austria                      59        78        81      218       48      77
# Azerbaijan                    0         0         0        0       10       6
# Bahamas                       0         0         0        0       15       5
# Bahrain                       0         0         0        0        8       0
# Barbados                      0         0         0        0       11       0
# Belarus                       6         4         5       15       11      18
# Belgium                       1         1         3        5       45      38
# Bermuda                       0         0         0        0       24       0
# Bohemia                       0         0         0        0        3       0
# Botswana                      0         0         0        0        9       0
# Brazil                        0         0         0        0       28      23
# British West Indies           0         0         0        0        1       0
# Bulgaria                      1         2         3        6       38      52
# Burundi                       0         0         0        0        5       1
# Cameroon                      0         0         0        0       14       3
# Canada                       62        56        52      170       47     121
# Chile                         0         0         0        0       38       2
# China                        12        22        19       53       19     213
# Colombia                      0         0         0        0       19       2
# Costa Rica                    0         0         0        0       20       1
# Ivory Coast                   0         0         0        0       12       0
# Croatia                       4         6         1       11       13      10
# Cuba                          0         0         0        0       19      72
# Cyprus                        0         0         0        0       19       0
# Czech Republic                7         9         8       24       11      21
# Czechoslovakia                2         8        15       25       32      51
# Denmark                       0         1         0        1       39      43
# Djibouti                      0         0         0        0        7       0
# Dominican Republic            0         0         0        0       13       3
# Ecuador                       0         0         0        0       13       1
# Egypt                         0         0         0        0       22       7
# Eritrea                       0         0         0        0        4       0
# Estonia                       4         2         1        7       20      13
# Ethiopia                      0         0         0        0       14      21
# Finland                      42        62        57      161       46     143
# France                       31        31        47      109       49     233
# Gabon                         0         0         0        0        9       0
# Georgia                       0         0         0        0       11       6
# Germany                      78        78        53      209       26     252
# United Team of Germany        8         6         5       19        6      36
# East Germany                 39        36        35      110       11     192
# West Germany                 11        15        13       39       11      67
# Ghana                         0         0         0        0       14       0
# Great Britain                10         4        12       26       49     246
# Greece                        0         0         0        0       45      30
# Grenada                       0         0         0        0        8       1
# Guatemala                     0         0         0        0       14       0
# Guyana                        0         0         0        0       16       0
# Haiti                         0         0         0        0       14       0
# Hong Kong                     0         0         0        0       19       1
# Hungary                       0         2         4        6       47     167
# Iceland                       0         0         0        0       36       0
# India                         0         0         0        0       32       9
# Indonesia                     0         0         0        0       14       6
#
#                          Silver.2  Bronze.2  Combined total   ID
# Afghanistan                     0         2               2  AFG
# Algeria                         2         8              15  ALG
# Argentina                      24        28              70  ARG
# Armenia                         2         9              12  ARM
# Australasia                     4         5              12  ANZ
# Australia                     155       181             480  AUS
# Austria                       111       116             304  AUT
# Azerbaijan                      5        15              26  AZE
# Bahamas                         2         5              12  BAH
# Bahrain                         0         1               1  BRN
# Barbados                        0         1               1  BAR
# Belarus                        28        44              90  BLR
# Belgium                        53        56             147  BEL
# Bermuda                         0         1               1  BER
# Bohemia                         1         3               4  BOH
# Botswana                        1         0               1  BOT
# Brazil                         30        55             108  BRA
# British West Indies             0         2               2  BWI
# Bulgaria                       87        81             220  BUL
# Burundi                         0         0               1  BDI
# Cameroon                        1         1               5  CMR
# Canada                        155       173             449  CAN
# Chile                           7         4              13  CHI
# China                         168       145             526  CHN
# Colombia                        6        11              19  COL
# Costa Rica                      1         2               4  CRC
# Ivory Coast                     1         0               1  CIV
# Croatia                        13        11              34  CRO
# Cuba                           67        70             209  CUB
# Cyprus                          1         0               1  CYP
# Czech Republic                 24        23              68  CZE
# Czechoslovakia                 57        60             168  TCH
# Denmark                        69        68             180  DEN
# Djibouti                        0         1               1  DJI
# Dominican Republic              2         1               6  DOM
# Ecuador                         1         0               2  ECU
# Egypt                           9        10              26  EGY
# Eritrea                         0         1               1  ERI
# Estonia                        11        16              40  EST
# Ethiopia                        7        17              45  ETH
# Finland                       146       174             463  FIN
# France                        254       293             780  FRA
# Gabon                           1         0               1  GAB
# Georgia                         5        14              25  GEO
# Germany                       260       270             782  GER
# United Team of Germany         60        41             137  EUA
# East Germany                  165       162             519  GDR
# West Germany                   82        94             243  FRG
# Ghana                           1         3               4  GHA
# Great Britain                 276       284             806  GBR
# Greece                         42        39             111  GRE
# Grenada                         0         0               1  GRN
# Guatemala                       1         0               1  GUA
# Guyana                          0         1               1  GUY
# Haiti                           1         1               2  HAI
# Hong Kong                       1         1               3  HKG
# Hungary                       146       169             482  HUN
# Iceland                         2         2               4  ISL
# India                           6        11              26  IND
# Indonesia                      10        11              27  INA

# %%
df["Gold"]
# Out:
# Afghanistan                             0
# Algeria                                 5
# Argentina                              18
# Armenia                                 1
# Australasia                             3
#                                      ...
# Independent Olympic Participants        0
# Zambia                                  0
# Zimbabwe                                3
# Mixed team                              8
# Totals                               4809
# Name: Gold, Length: 147, dtype: int64
